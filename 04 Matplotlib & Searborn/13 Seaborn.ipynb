# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="darkgrid")

# %%
x = np.array([1,2,56,6,46,65,25,45,58,63,25,98])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
