# %%
import matplotlib.pyplot as plt

# %%
years = [1980,1985,1990,1995,2000,2005,2010,2015,2020,2025]
kohli = [550,755,665,995,663,556,985,634,559,887]
rohit = [664,336,587,964,852,159,657,856,999,657]
sehwag = [657,546,957,856,856,785,439,974,226,885]

plt.plot(years, kohli, label ="Virat kohli")
plt.plot(years, rohit, label = "rohit sharma")
plt.plot(years, sehwag, label = "sehwag")

plt.xlabel("Years")
plt.ylabel("Runs scored")
plt.title("10 Years hypothetical runs")
plt.legend()
